# %%
# Imports
from scipy.stats import chi2_contingency
from scipy.stats import chi2

from itertools import combinations

import pandas as pd

pd.set_option('display.max_columns', None) # Print all columns to jupyter notebook


def is_dependent(df, attr1, attr2, significance=0.05):
    # Returns True if attr1 and attr2 in a specificied
    # dataframe are considered dependent using the Chi^2 test
    
    observation = create_observation_table(df, attr1, attr2)
    chi, pval, dof, exp = chi2_contingency(observation)
    
    p = 1 - significance
    
    critical_value = chi2.ppf(p, dof)
    
    return (chi > critical_value)


def create_observation_table(df, attr1, attr2):
    # Creates the observation table for two attributes
    # in a specified dataframe
    
    # Get unique values for attributes
    index = df[attr1].unique()
    cols = df[attr2].unique()

    # Sort elements in cols/index
    [arr.sort() for arr in [index, cols]]
    
    # Create empty table
    observation = pd.DataFrame([], index=index, columns=cols)
    
    # Insert data
    for idx, val in df.groupby([attr1, attr2]).size().items():
        row, col = idx
        observation[col].loc[row] = val
        
    observation.fillna(0, inplace=True)
        
    return observation


if __name__ == '__main__':
    # Read from data source
    DATA_SOURCE = r'../data/credit_output.csv'
    DATA_SOURCE = r'../data/credit_output_test_binned.csv'

    df = pd.read_csv(DATA_SOURCE)

#     # List of all nominal attributes
#     nominal_attributes = [
#         'personal_status', 
#         'own_telephone', 
#         'job', 
#         'other_parties', 
#         'works_outside_US', 
#         'purpose', 
#         'foreign_worker', 
#         'location', 
#         'property_magnitude', 
#         'housing', 
#         'employment', 
#         'state',
#         'other_payment_plans', 
#         'class', 
#         'credit_history',
#         'installment_commitment', # These last 3 are numerical but because
#         'residence_since',        # small range of values they can act as categorical
#         'existing_credits'        #
#     ]


    nominal_attributes = ['location', 
            'state', 
            'credit_history',
            'purpose', 
            'employment',
            'installment_commitment', 
            'personal_status', 
            'other_parties',
            'residence_since', 
            'property_magnitude', 
            'age', 
            'other_payment_plans',
            'housing', 
            'existing_credits', 
            'job', 
            'num_dependents', 
            'own_telephone',
            'foreign_worker', 
            'year', 
            'month', 
            'checking_amt_b', 
            'savings_b', 
            'credit_amount_b', 
            'duration_b',
            'total_b', 
            'proportion_b', 
            'class']
    
    corr_count = {k: 0 for k in nominal_attributes}

    
    # Iterate through combinations, determine dependence
    for c in combinations(nominal_attributes, 2):
        is_corr = is_dependent(df, *c)
        if is_corr:
            for attr in c:
                corr_count[attr] += 1
            print(f'{str(c[0]) + " & " + str(c[1]):<50}: {is_corr}')
    
    print('\n\n')
    for k in sorted(corr_count, key=lambda x: corr_count[x]):
        print(f'{str(k):<25} : {str(corr_count[k])}')
# Out:
# location & state                                  : True
# location & employment                             : True
# location & year                                   : True
# location & month                                  : True
# state & year                                      : True
# state & month                                     : True
# credit_history & purpose                          : True
# credit_history & employment                       : True
# credit_history & personal_status                  : True
# credit_history & residence_since                  : True
# credit_history & age                              : True
# credit_history & existing_credits                 : True
# credit_history & checking_amt_b                   : True
# credit_history & credit_amount_b                  : True
# credit_history & duration_b                       : True
# credit_history & total_b                          : True
# credit_history & proportion_b                     : True
# purpose & installment_commitment                  : True
# purpose & personal_status                         : True
# purpose & property_magnitude                      : True
# purpose & age                                     : True
# purpose & housing                                 : True
# purpose & job                                     : True
# purpose & num_dependents                          : True
# purpose & own_telephone                           : True
# purpose & credit_amount_b                         : True
# purpose & duration_b                              : True
# purpose & total_b                                 : True
# purpose & proportion_b                            : True
# employment & personal_status                      : True
# employment & residence_since                      : True
# employment & property_magnitude                   : True
# employment & age                                  : True
# employment & housing                              : True
# employment & existing_credits                     : True
# employment & job                                  : True
# employment & own_telephone                        : True
# employment & proportion_b                         : True
# installment_commitment & personal_status          : True
# installment_commitment & credit_amount_b          : True
# installment_commitment & duration_b               : True
# installment_commitment & total_b                  : True
# personal_status & residence_since                 : True
# personal_status & property_magnitude              : True
# personal_status & age                             : True
# personal_status & housing                         : True
# personal_status & num_dependents                  : True
# personal_status & own_telephone                   : True
# personal_status & credit_amount_b                 : True
# personal_status & duration_b                      : True
# personal_status & total_b                         : True
# other_parties & property_magnitude                : True
# other_parties & checking_amt_b                    : True
# other_parties & savings_b                         : True
# other_parties & total_b                           : True
# other_parties & proportion_b                      : True
# residence_since & property_magnitude              : True
# residence_since & age                             : True
# residence_since & housing                         : True
# residence_since & existing_credits                : True
# property_magnitude & age                          : True
# property_magnitude & other_payment_plans          : True
# property_magnitude & housing                      : True
# property_magnitude & job                          : True
# property_magnitude & own_telephone                : True
# property_magnitude & credit_amount_b              : True
# property_magnitude & duration_b                   : True
# property_magnitude & total_b                      : True
# age & housing                                     : True
# age & existing_credits                            : True
# age & job                                         : True
# age & num_dependents                              : True
# age & own_telephone                               : True
# age & savings_b                                   : True
# other_payment_plans & duration_b                  : True
# housing & existing_credits                        : True
# housing & job                                     : True
# housing & num_dependents                          : True
# housing & own_telephone                           : True
# housing & credit_amount_b                         : True
# housing & duration_b                              : True
# existing_credits & job                            : True
# job & num_dependents                              : True
# job & own_telephone                               : True
# job & credit_amount_b                             : True
# job & duration_b                                  : True
# job & total_b                                     : True
# job & proportion_b                                : True
# own_telephone & credit_amount_b                   : True
# own_telephone & duration_b                        : True
# own_telephone & total_b                           : True
# own_telephone & proportion_b                      : True
# year & month                                      : True
# year & duration_b                                 : True
# month & total_b                                   : True
# checking_amt_b & savings_b                        : True
# checking_amt_b & total_b                          : True
# checking_amt_b & proportion_b                     : True
# savings_b & total_b                               : True
# savings_b & proportion_b                          : True
# credit_amount_b & duration_b                      : True
# credit_amount_b & total_b                         : True
# credit_amount_b & proportion_b                    : True
# duration_b & total_b                              : True
# duration_b & proportion_b                         : True
# total_b & proportion_b                            : True
#
#
#
# foreign_worker            : 0
# class                     : 0
# other_payment_plans       : 2
# state                     : 3
# location                  : 4
# year                      : 4
# month                     : 4
# installment_commitment    : 5
# other_parties             : 5
# num_dependents            : 5
# checking_amt_b            : 5
# savings_b                 : 5
# existing_credits          : 6
# residence_since           : 7
# credit_history            : 11
# employment                : 11
# own_telephone             : 11
# credit_amount_b           : 11
# proportion_b              : 11
# age                       : 12
# housing                   : 12
# job                       : 12
# purpose                   : 13
# personal_status           : 13
# property_magnitude        : 13
# duration_b                : 13
# total_b                   : 14

# %%
create_observation_table(df, 'works_outside_US', 'foreign_worker')
# Out:
#       NO  YES
# NO   459    0
# YES    0  531
